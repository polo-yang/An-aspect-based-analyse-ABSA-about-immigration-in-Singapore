# %%
# For sending GET requests from the API
import requests
# For saving access tokens and for file management when creating and adding to the dataset
import os
# For dealing with json responses we receive from the API
import json
# For displaying the data after
import pandas as pd
# For saving the response data in CSV format
import csv
# For parsing the dates received from twitter in readable formats
import datetime
import dateutil.parser
import unicodedata
#To add wait time between requests
import time

# %%
os.environ['TOKEN'] = 'AAAAAAAAAAAAAAAAAAAAAJdLZAEAAAAAMWhCHY72Kktv1lqRSVqD1SQYtEY%3DOWQVaHlBhM3J10Hnl0zaBij6YOsJMefe0pvkMDrlCoZXaFhlfW'

def auth():
    return os.getenv('TOKEN')

# %%
def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers

# %%
def create_url(keyword, start_date, end_date, max_results = 10):
    
    search_url = "https://api.twitter.com/2/tweets/search/all" #Change to the endpoint you want to collect data from

    #change params based on the endpoint you are using
    query_params = {'query': keyword,
                    'start_time': start_date,
                    'end_time': end_date,
                    'max_results': max_results,

                    'expansions': 'author_id,in_reply_to_user_id,geo.place_id',
                    'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source',
                    'user.fields': 'id,name,username,created_at,description,public_metrics,verified',
                    'place.fields': 'full_name,id,country,country_code,geo,name,place_type',
                    'next_token': {}}
    return (search_url, query_params)

# %%
#不用动
def connect_to_endpoint(url, headers, params,  next_token = None):
    params['next_token'] = next_token   #params object received from create_url function
    response = requests.request("GET", url, headers = headers, params = params)
    print("Endpoint Response Code: " + str(response.status_code))
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
#Inputs for the request
bearer_token = auth()
headers = create_headers(bearer_token)
keyword = "singapore EP lang:en"
start_time = "2006-04-01T00:00:00.000Z"
end_time = "2021-03-02T00:00:00.000Z"
max_results = 15

# %%
url = create_url(keyword, start_time,end_time, max_results)
json_response = connect_to_endpoint(url[0], headers, url[1])
print(json.dumps(json_response, indent=4, sort_keys=True))
# Out:
# Endpoint Response Code: 200
# {
#     "data": [
#         {
#             "author_id": "328850899",
#             "conversation_id": "1366441713955438599",
#             "created_at": "2021-03-01T17:34:26.000Z",
#             "id": "1366441713955438599",
#             "in_reply_to_user_id": "545098699",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 1
#             },
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "@KadeemKing_ X @ThemeMusicJosh are dropping their collab EP \u201cFashion From Singapore\u201d on MARCH 8th!!! I\u2019m blessed to be featured on it as well. SO STAY TUNED! https://t.co/iS017X7unD"
#         },
#         {
#             "author_id": "1014593275968344065",
#             "conversation_id": "1366329751485480961",
#             "created_at": "2021-03-01T10:09:32.000Z",
#             "id": "1366329751485480961",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 1
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1366329696238112770",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitch Hashtag Retweet ",
#             "text": "RT @Riyou_Kisa: 200 followers Party #karaoke #oxygennotincluded #ApexLegends feat. @InSainyaka  &amp;  @zithophen   Ep 22\nhttps://t.co/ciDsXgtW\u2026"
#         },
#         {
#             "author_id": "602673378",
#             "conversation_id": "1366329696238112770",
#             "created_at": "2021-03-01T10:09:19.000Z",
#             "id": "1366329696238112770",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 1
#             },
#             "reply_settings": "everyone",
#             "source": "Streamlabs Twitter",
#             "text": "200 followers Party #karaoke #oxygennotincluded #ApexLegends feat. @InSainyaka  &amp;  @zithophen   Ep 22\nhttps://t.co/ciDsXgtWmd\n#vtuber #VtuberEn #schedule #sgstreamers #singapore #TwitchPartnership #twitchgoals #milestones #SGVT #fps #200followers #livenow #nowstreaming #klei"
#         },
#         {
#             "author_id": "57611976",
#             "conversation_id": "1364570965238194176",
#             "created_at": "2021-03-01T09:15:36.000Z",
#             "id": "1366316176519753733",
#             "in_reply_to_user_id": "918088683516870656",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1366315409805172736",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "@Ep_0052 hello! are u from singapore? bc i found the bottles using the singapore app!"
#         },
#         {
#             "author_id": "602673378",
#             "conversation_id": "1366302951770234880",
#             "created_at": "2021-03-01T08:23:03.000Z",
#             "id": "1366302951770234880",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 3,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "Today's Party Schedule #karaoke #oxygennotincluded #ApexLegends feat. @InSainyaka &amp; @zithophen  Ep 21\nhttps://t.co/ciDsXgLxdL\n\n#vtuber #VtuberEn #schedule #sgstreamers #singapore #TwitchPartnership #twitchgoals #milestones #SGVT #fps #200followers https://t.co/3HzH0fehC8"
#         },
#         {
#             "author_id": "139872196",
#             "conversation_id": "1366217237963677698",
#             "created_at": "2021-03-01T02:42:27.000Z",
#             "id": "1366217237963677698",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 4
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "804556374864699392",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPad",
#             "text": "RT @TrueCrimeAsia: Our first ep is on #Soundcloud! \n\nIt's the story of #Singapore's #AdrianLim. \ud83c\uddf8\ud83c\uddec Occult, murder, kidnap, and worse.\n\nhttp\u2026"
#         }
#     ],
#     "includes": {
#         "users": [
#             {
#                 "created_at": "2011-07-04T04:16:34.000Z",
#                 "description": "RECORDING ARTIST & SONGWRITER \u270d DreamFrxxRealm - \u201cLINES OF SYMMETRY\u201d NOW STREAMING EVERYWHERE!!! \u2b07\ufe0f\u2b07\ufe0f\u2b07\ufe0f\u2b07\ufe0f\u2b07\ufe0f\u2b07\ufe0f\u2b07\ufe0f\u2b07\ufe0f\u2b07\ufe0f",
#                 "id": "328850899",
#                 "name": "WAV.AURA.VIBE.FRXX",
#                 "public_metrics": {
#                     "followers_count": 350,
#                     "following_count": 552,
#                     "listed_count": 3,
#                     "tweet_count": 10525
#                 },
#                 "username": "shavaarmusic",
#                 "verified": false
#             },
#             {
#                 "created_at": "2012-04-04T12:43:49.000Z",
#                 "description": "Kadeem King (IG: @KadeemKing_) #LEADAH TheREBpublic1@gmail.com",
#                 "id": "545098699",
#                 "name": "LEADAH",
#                 "public_metrics": {
#                     "followers_count": 1397,
#                     "following_count": 732,
#                     "listed_count": 19,
#                     "tweet_count": 31022
#                 },
#                 "username": "KadeemKing_",
#                 "verified": false
#             },
#             {
#                 "created_at": "2018-07-04T19:34:22.000Z",
#                 "description": "Use @TwitchSIE \n\ud835\ude73\ud835\ude78\ud835\ude82\ud835\ude72\ud835\ude7e\ud835\ude81\ud835\ude73: https://t.co/KHfrBLk5tJ \nTwitch: https://t.co/3l601NfIGk\n\nDISCLAIMER: We are not Affiliated With @Twitch",
#                 "id": "1014593275968344065",
#                 "name": "Twitch Community",
#                 "public_metrics": {
#                     "followers_count": 32445,
#                     "following_count": 270,
#                     "listed_count": 61,
#                     "tweet_count": 852647
#                 },
#                 "username": "TwitchSIE",
#                 "verified": false
#             },
#             {
#                 "created_at": "2012-06-08T08:48:09.000Z",
#                 "description": "#Commission\uff0dOpen & \ud83d\udd28\ud83d\udd27\ud83e\ude9b-\n#Artist | #Cosplayer | #Streamer | #SGVtuber\nRT\ud83c\udd97| Repost\ud83d\udeab | I\ud83d\udc99#miku 3\ufe0f\u20e39\ufe0f\u20e3\n\u592b: @zithophen\n| DP: @cheshirino \nhttps://t.co/jE3ifM5FEw",
#                 "id": "602673378",
#                 "name": "COMMS wait list OPEN RK3-Riyou Kisa \ud83d\udc3e",
#                 "public_metrics": {
#                     "followers_count": 655,
#                     "following_count": 1137,
#                     "listed_count": 13,
#                     "tweet_count": 8665
#                 },
#                 "username": "Riyou_Kisa",
#                 "verified": false
#             },
#             {
#                 "created_at": "2009-07-17T10:44:42.000Z",
#                 "description": "@realjonghyun90 you have done well \u2728",
#                 "id": "57611976",
#                 "name": "\ucad1",
#                 "public_metrics": {
#                     "followers_count": 1819,
#                     "following_count": 282,
#                     "listed_count": 25,
#                     "tweet_count": 124977
#                 },
#                 "username": "dinojong",
#                 "verified": false
#             },
#             {
#                 "created_at": "2017-10-11T12:19:34.000Z",
#                 "description": "1st Simu Liu Hong Kong Fanclub \u9999\u6e2f\u9996\u7ad9 Started out on Instagram with the same username @SimuLiu \ud83d\udc99",
#                 "id": "918088683516870656",
#                 "name": "Simu Liu Hong Kong Fans",
#                 "public_metrics": {
#                     "followers_count": 40,
#                     "following_count": 24,
#                     "listed_count": 0,
#                     "tweet_count": 190
#                 },
#                 "username": "simuliuhk",
#                 "verified": false
#             },
#             {
#                 "created_at": "2010-05-03T22:56:39.000Z",
#                 "description": "Life Is A Kind Of Music",
#                 "id": "139872196",
#                 "name": "Ronald Clarke",
#                 "public_metrics": {
#                     "followers_count": 3133,
#                     "following_count": 94,
#                     "listed_count": 637,
#                     "tweet_count": 789912
#                 },
#                 "username": "RonaldClarke",
#                 "verified": false
#             }
#         ]
#     },
#     "meta": {
#         "newest_id": "1366441713955438599",
#         "next_token": "b26v89c19zqg8o3fosntcmkniccodlb3ee2kk89zsx5rx",
#         "oldest_id": "1366217237963677698",
#         "result_count": 6
#     }
# }

# %%
def append_to_csv(json_response, fileName):

    #A counter variable
    counter = 0

    #Open OR create the target CSV file
    csvFile = open(fileName, "a", newline="", encoding='utf-8')
    csvWriter = csv.writer(csvFile)

    #Loop through each tweet
    for tweet in json_response['data']:
        
        # We will create a variable for each since some of the keys might not exist for some tweets
        # So we will account for that

        # 1. Author ID
        author_id = tweet['author_id']

        # 2. Time created
        created_at = dateutil.parser.parse(tweet['created_at'])

        # 3. Geolocation
        if ('geo' in tweet):   
            geo = " "
        else:
            geo = " "

        # 4. Tweet ID
        tweet_id = tweet['id']

        # 5. Language
        lang = tweet['lang']

        # 6. Tweet metrics
        retweet_count = tweet['public_metrics']['retweet_count']
        reply_count = tweet['public_metrics']['reply_count']
        like_count = tweet['public_metrics']['like_count']
        quote_count = tweet['public_metrics']['quote_count']

        # 7. source
        source = " "

        # 8. Tweet text
        text = tweet['text']
        
        # Assemble all data in a list
        res = [author_id, created_at, geo, tweet_id, lang, like_count, quote_count, reply_count, retweet_count, source, text]
        
        # Append the result to the CSV file
        csvWriter.writerow(res)
        counter += 1

    # When done, close the CSV file
    csvFile.close()

    # Print the number of tweets for this iteration
    print("# of Tweets added from this response: ", counter)

# %%
#Inputs for tweets
bearer_token = auth()
headers = create_headers(bearer_token)
keyword = "Singapore expatriate lang:en"
###############################################################
start_list =    ['2006-04-01T00:00:00.000Z',
                 '2006-05-01T00:00:00.000Z',
                 '2006-06-01T00:00:00.000Z',
                 '2006-07-01T00:00:00.000Z',
                 '2006-08-01T00:00:00.000Z',
                 '2006-09-01T00:00:00.000Z',
                 '2006-10-01T00:00:00.000Z',
                 '2006-11-01T00:00:00.000Z',
                 '2006-12-01T00:00:00.000Z',
                 '2007-01-01T00:00:00.000Z',
                 '2007-02-01T00:00:00.000Z',
                 '2007-03-01T00:00:00.000Z',
                 '2007-04-01T00:00:00.000Z',
                 '2007-05-01T00:00:00.000Z',
                 '2007-06-01T00:00:00.000Z',
                 '2007-07-01T00:00:00.000Z',
                 '2007-08-01T00:00:00.000Z',
                 '2007-09-01T00:00:00.000Z',
                 '2007-10-01T00:00:00.000Z',
                 '2007-11-01T00:00:00.000Z',
                 '2007-12-01T00:00:00.000Z',
                 '2008-01-01T00:00:00.000Z',
                 '2008-02-01T00:00:00.000Z',
                 '2008-03-01T00:00:00.000Z',
                 '2008-04-01T00:00:00.000Z',
                 '2008-05-01T00:00:00.000Z',
                 '2008-06-01T00:00:00.000Z',
                 '2008-07-01T00:00:00.000Z',
                 '2008-08-01T00:00:00.000Z',
                 '2008-09-01T00:00:00.000Z',
                 '2008-10-01T00:00:00.000Z',
                 '2008-11-01T00:00:00.000Z',
                 '2008-12-01T00:00:00.000Z',
                 '2009-01-01T00:00:00.000Z',
                 '2009-02-01T00:00:00.000Z',
                 '2009-03-01T00:00:00.000Z',
                 '2009-04-01T00:00:00.000Z',
                 '2009-05-01T00:00:00.000Z',
                 '2009-06-01T00:00:00.000Z',
                 '2009-07-01T00:00:00.000Z',
                 '2009-08-01T00:00:00.000Z',
                 '2009-09-01T00:00:00.000Z',
                 '2009-10-01T00:00:00.000Z',
                 '2009-11-01T00:00:00.000Z',
                 '2009-12-01T00:00:00.000Z',
                 '2010-01-01T00:00:00.000Z',
                 '2010-02-01T00:00:00.000Z',
                 '2010-03-01T00:00:00.000Z',
                 '2010-04-01T00:00:00.000Z',
                 '2018-07-30T00:00:00.000Z',
                 '2018-08-30T00:00:00.000Z',
                 '2018-09-30T00:00:00.000Z',
                 '2018-10-30T00:00:00.000Z',
                 '2018-11-30T00:00:00.000Z',
                 '2018-12-30T00:00:00.000Z',
                 '2019-01-30T00:00:00.000Z',
                 '2019-02-28T00:00:00.000Z',
                 '2019-03-30T00:00:00.000Z',
                 '2019-04-30T00:00:00.000Z',
                 '2019-05-30T00:00:00.000Z',
                 '2019-06-30T00:00:00.000Z',
                 '2019-07-30T00:00:00.000Z',
                 '2019-08-30T00:00:00.000Z',
                 '2019-09-30T00:00:00.000Z',
                 '2019-10-30T00:00:00.000Z',
                 '2019-11-30T00:00:00.000Z',
                 '2019-12-30T00:00:00.000Z',
                 '2020-01-30T00:00:00.000Z',
                 '2020-02-28T00:00:00.000Z',
                 '2020-03-30T00:00:00.000Z',
                 '2020-04-30T00:00:00.000Z',
                 '2020-05-30T00:00:00.000Z',
                 '2020-06-30T00:00:00.000Z',
                 '2020-07-30T00:00:00.000Z',
                 '2020-08-30T00:00:00.000Z',
                 '2020-09-30T00:00:00.000Z',
                 '2020-10-30T00:00:00.000Z',
                 '2020-11-30T00:00:00.000Z',
                 '2020-12-30T00:00:00.000Z',
                 '2021-01-30T00:00:00.000Z',
                 '2021-02-28T00:00:00.000Z',
                 '2021-03-30T00:00:00.000Z',
                 '2021-04-30T00:00:00.000Z',
                 '2021-05-30T00:00:00.000Z',
                 '2021-06-30T00:00:00.000Z',
                 '2021-07-30T00:00:00.000Z',
                 '2021-08-30T00:00:00.000Z',
                 '2021-09-30T00:00:00.000Z',
                 '2021-10-30T00:00:00.000Z',
                 '2021-11-30T00:00:00.000Z',
                 '2021-12-30T00:00:00.000Z',
                 '2022-01-30T00:00:00.000Z',
                 '2022-02-28T00:00:00.000Z',
                 '2022-03-21T00:00:00.000Z',]

max_results = 400

#Total number of tweets we collected from the loop
total_tweets = 0

# Create file
csvFile = open("expatriate.csv", "a", newline="", encoding='utf-8')
##################################################################################
csvWriter = csv.writer(csvFile)

#Create headers for the data you want to save, in this example, we only want save these columns in our dataset
csvWriter.writerow(['author id', 'created_at', 'geo', 'id','lang', 'like_count', 'quote_count', 'reply_count','retweet_count','source','tweet'])
csvFile.close()

for i in range(0,len(start_list)):

    # Inputs
    count = 0 # Counting tweets per time period
    max_count = 100 # Max tweets per time period
    flag = True
    next_token = None
    
    # Check if flag is true
    while flag:
        # Check if max_count reached
        if count >= max_count:
            break
        print("-------------------")
        print("Token: ", next_token)
        url = create_url(keyword, start_list[i],end_list[i], max_results)
        json_response = connect_to_endpoint(url[0], headers, url[1], next_token)
        result_count = json_response['meta']['result_count']

        if 'next_token' in json_response['meta']:
            # Save the token to use for next call
            next_token = json_response['meta']['next_token']
            print("Next Token: ", next_token)
            if result_count is not None and result_count > 0 and next_token is not None:
                print("Start Date: ", start_list[i])
                append_to_csv(json_response, "expatriate.csv")
                ##################################################
                count += result_count
                total_tweets += result_count
                print("Total # of Tweets added: ", total_tweets)
                print("-------------------")
                time.sleep(5)                
        # If no next token exists
        else:
            if result_count is not None and result_count > 0:
                print("-------------------")
                print("Start Date: ", start_list[i])
                append_to_csv(json_response, "expatriate.csv")
                ###########################################################
                count += result_count
                total_tweets += result_count
                print("Total # of Tweets added: ", total_tweets)
                print("-------------------")
                time.sleep(5)
            
            #Since this is the final request, turn flag to false to move to the next time period.
            flag = False
            next_token = None
        time.sleep(5)
print("Total number of results: ", total_tweets)
# Out:
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2007-12-01T00:00:00.000Z
# # of Tweets added from this response:  1
# Total # of Tweets added:  1
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2008-01-01T00:00:00.000Z
# # of Tweets added from this response:  1
# Total # of Tweets added:  2
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2008-07-01T00:00:00.000Z
# # of Tweets added from this response:  1
# Total # of Tweets added:  3
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2008-08-01T00:00:00.000Z
# # of Tweets added from this response:  1
# Total # of Tweets added:  4
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2008-10-01T00:00:00.000Z
# # of Tweets added from this response:  1
# Total # of Tweets added:  5
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2009-03-01T00:00:00.000Z
# # of Tweets added from this response:  3
# Total # of Tweets added:  8
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2009-06-01T00:00:00.000Z
# # of Tweets added from this response:  1
# Total # of Tweets added:  9
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2009-07-01T00:00:00.000Z
# # of Tweets added from this response:  6
# Total # of Tweets added:  15
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2009-08-01T00:00:00.000Z
# # of Tweets added from this response:  2
# Total # of Tweets added:  17
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2009-10-01T00:00:00.000Z
# # of Tweets added from this response:  1
# Total # of Tweets added:  18
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2009-11-01T00:00:00.000Z
# # of Tweets added from this response:  2
# Total # of Tweets added:  20
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2010-01-01T00:00:00.000Z
# # of Tweets added from this response:  4
# Total # of Tweets added:  24
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2010-02-01T00:00:00.000Z
# # of Tweets added from this response:  14
# Total # of Tweets added:  38
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2010-03-01T00:00:00.000Z
# # of Tweets added from this response:  18
# Total # of Tweets added:  56
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2010-04-01T00:00:00.000Z
# # of Tweets added from this response:  5
# Total # of Tweets added:  61
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2010-05-01T00:00:00.000Z
# # of Tweets added from this response:  11
# Total # of Tweets added:  72
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2010-06-01T00:00:00.000Z
# # of Tweets added from this response:  19
# Total # of Tweets added:  91
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2010-07-01T00:00:00.000Z
# # of Tweets added from this response:  10
# Total # of Tweets added:  101
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2010-08-01T00:00:00.000Z
# # of Tweets added from this response:  13
# Total # of Tweets added:  114
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2010-09-01T00:00:00.000Z
# # of Tweets added from this response:  6
# Total # of Tweets added:  120
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2010-10-01T00:00:00.000Z
# # of Tweets added from this response:  7
# Total # of Tweets added:  127
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2010-11-01T00:00:00.000Z
# # of Tweets added from this response:  21
# Total # of Tweets added:  148
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2010-12-01T00:00:00.000Z
# # of Tweets added from this response:  19
# Total # of Tweets added:  167
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2011-01-01T00:00:00.000Z
# # of Tweets added from this response:  14
# Total # of Tweets added:  181
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2011-02-01T00:00:00.000Z
# # of Tweets added from this response:  26
# Total # of Tweets added:  207
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2011-03-01T00:00:00.000Z
# # of Tweets added from this response:  13
# Total # of Tweets added:  220
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2011-04-01T00:00:00.000Z
# # of Tweets added from this response:  13
# Total # of Tweets added:  233
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2011-05-01T00:00:00.000Z
# # of Tweets added from this response:  5
# Total # of Tweets added:  238
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2011-06-01T00:00:00.000Z
# # of Tweets added from this response:  20
# Total # of Tweets added:  258
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2011-07-01T00:00:00.000Z
# # of Tweets added from this response:  4
# Total # of Tweets added:  262
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2011-08-01T00:00:00.000Z
# # of Tweets added from this response:  17
# Total # of Tweets added:  279
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2011-09-01T00:00:00.000Z
# # of Tweets added from this response:  30
# Total # of Tweets added:  309
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2011-10-01T00:00:00.000Z
# # of Tweets added from this response:  19
# Total # of Tweets added:  328
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2011-11-01T00:00:00.000Z
# # of Tweets added from this response:  39
# Total # of Tweets added:  367
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2011-12-01T00:00:00.000Z
# # of Tweets added from this response:  23
# Total # of Tweets added:  390
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2012-01-01T00:00:00.000Z
# # of Tweets added from this response:  48
# Total # of Tweets added:  438
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2012-02-01T00:00:00.000Z
# # of Tweets added from this response:  5
# Total # of Tweets added:  443
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2012-03-01T00:00:00.000Z
# # of Tweets added from this response:  23
# Total # of Tweets added:  466
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2012-04-01T00:00:00.000Z
# # of Tweets added from this response:  26
# Total # of Tweets added:  492
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2012-05-01T00:00:00.000Z
# # of Tweets added from this response:  44
# Total # of Tweets added:  536
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2012-06-01T00:00:00.000Z
# # of Tweets added from this response:  18
# Total # of Tweets added:  554
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2012-07-01T00:00:00.000Z
# # of Tweets added from this response:  35
# Total # of Tweets added:  589
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2012-08-01T00:00:00.000Z
# # of Tweets added from this response:  15
# Total # of Tweets added:  604
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2012-09-01T00:00:00.000Z
# # of Tweets added from this response:  12
# Total # of Tweets added:  616
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2012-10-01T00:00:00.000Z
# # of Tweets added from this response:  8
# Total # of Tweets added:  624
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2012-11-01T00:00:00.000Z
# # of Tweets added from this response:  17
# Total # of Tweets added:  641
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2012-12-01T00:00:00.000Z
# # of Tweets added from this response:  13
# Total # of Tweets added:  654
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2013-01-01T00:00:00.000Z
# # of Tweets added from this response:  12
# Total # of Tweets added:  666
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2013-02-01T00:00:00.000Z
# # of Tweets added from this response:  11
# Total # of Tweets added:  677
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2013-03-01T00:00:00.000Z
# # of Tweets added from this response:  36
# Total # of Tweets added:  713
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2013-04-01T00:00:00.000Z
# # of Tweets added from this response:  12
# Total # of Tweets added:  725
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2013-05-01T00:00:00.000Z
# # of Tweets added from this response:  1
# Total # of Tweets added:  726
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2013-06-01T00:00:00.000Z
# # of Tweets added from this response:  7
# Total # of Tweets added:  733
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2013-07-01T00:00:00.000Z
# # of Tweets added from this response:  43
# Total # of Tweets added:  776
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2013-08-01T00:00:00.000Z
# # of Tweets added from this response:  7
# Total # of Tweets added:  783
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2013-09-01T00:00:00.000Z
# # of Tweets added from this response:  22
# Total # of Tweets added:  805
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2013-10-01T00:00:00.000Z
# # of Tweets added from this response:  55
# Total # of Tweets added:  860
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2013-11-01T00:00:00.000Z
# # of Tweets added from this response:  37
# Total # of Tweets added:  897
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2013-12-01T00:00:00.000Z
# # of Tweets added from this response:  19
# Total # of Tweets added:  916
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2014-01-01T00:00:00.000Z
# # of Tweets added from this response:  40
# Total # of Tweets added:  956
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2014-02-01T00:00:00.000Z
# # of Tweets added from this response:  74
# Total # of Tweets added:  1030
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2014-03-01T00:00:00.000Z
# # of Tweets added from this response:  173
# Total # of Tweets added:  1203
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2014-04-01T00:00:00.000Z
# # of Tweets added from this response:  87
# Total # of Tweets added:  1290
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2014-05-01T00:00:00.000Z
# # of Tweets added from this response:  23
# Total # of Tweets added:  1313
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2014-06-01T00:00:00.000Z
# # of Tweets added from this response:  7
# Total # of Tweets added:  1320
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2014-07-01T00:00:00.000Z
# # of Tweets added from this response:  2
# Total # of Tweets added:  1322
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2014-08-01T00:00:00.000Z
# # of Tweets added from this response:  9
# Total # of Tweets added:  1331
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2014-09-01T00:00:00.000Z
# # of Tweets added from this response:  27
# Total # of Tweets added:  1358
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2014-10-01T00:00:00.000Z
# # of Tweets added from this response:  79
# Total # of Tweets added:  1437
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2014-11-01T00:00:00.000Z
# # of Tweets added from this response:  29
# Total # of Tweets added:  1466
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2014-12-01T00:00:00.000Z
# # of Tweets added from this response:  16
# Total # of Tweets added:  1482
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2015-01-01T00:00:00.000Z
# # of Tweets added from this response:  15
# Total # of Tweets added:  1497
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2015-02-01T00:00:00.000Z
# # of Tweets added from this response:  8
# Total # of Tweets added:  1505
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2015-03-01T00:00:00.000Z
# # of Tweets added from this response:  13
# Total # of Tweets added:  1518
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2015-04-01T00:00:00.000Z
# # of Tweets added from this response:  11
# Total # of Tweets added:  1529
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2015-05-01T00:00:00.000Z
# # of Tweets added from this response:  47
# Total # of Tweets added:  1576
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2015-06-01T00:00:00.000Z
# # of Tweets added from this response:  33
# Total # of Tweets added:  1609
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2015-07-01T00:00:00.000Z
# # of Tweets added from this response:  6
# Total # of Tweets added:  1615
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2015-08-01T00:00:00.000Z
# # of Tweets added from this response:  10
# Total # of Tweets added:  1625
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2015-09-01T00:00:00.000Z
# # of Tweets added from this response:  6
# Total # of Tweets added:  1631
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2015-10-01T00:00:00.000Z
# # of Tweets added from this response:  48
# Total # of Tweets added:  1679
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2015-11-01T00:00:00.000Z
# # of Tweets added from this response:  8
# Total # of Tweets added:  1687
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2015-12-01T00:00:00.000Z
# # of Tweets added from this response:  5
# Total # of Tweets added:  1692
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2016-01-01T00:00:00.000Z
# # of Tweets added from this response:  2
# Total # of Tweets added:  1694
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2016-02-01T00:00:00.000Z
# # of Tweets added from this response:  58
# Total # of Tweets added:  1752
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2016-03-01T00:00:00.000Z
# # of Tweets added from this response:  43
# Total # of Tweets added:  1795
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2016-04-01T00:00:00.000Z
# # of Tweets added from this response:  8
# Total # of Tweets added:  1803
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2016-05-01T00:00:00.000Z
# # of Tweets added from this response:  7
# Total # of Tweets added:  1810
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2016-06-01T00:00:00.000Z
# # of Tweets added from this response:  4
# Total # of Tweets added:  1814
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2016-07-01T00:00:00.000Z
# # of Tweets added from this response:  19
# Total # of Tweets added:  1833
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2016-08-01T00:00:00.000Z
# # of Tweets added from this response:  28
# Total # of Tweets added:  1861
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2016-09-01T00:00:00.000Z
# # of Tweets added from this response:  40
# Total # of Tweets added:  1901
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2016-10-01T00:00:00.000Z
# # of Tweets added from this response:  3
# Total # of Tweets added:  1904
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2016-11-01T00:00:00.000Z
# # of Tweets added from this response:  24
# Total # of Tweets added:  1928
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2016-12-01T00:00:00.000Z
# # of Tweets added from this response:  32
# Total # of Tweets added:  1960
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2017-01-01T00:00:00.000Z
# # of Tweets added from this response:  13
# Total # of Tweets added:  1973
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2017-02-01T00:00:00.000Z
# # of Tweets added from this response:  3
# Total # of Tweets added:  1976
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2017-03-01T00:00:00.000Z
# # of Tweets added from this response:  17
# Total # of Tweets added:  1993
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2017-04-01T00:00:00.000Z
# # of Tweets added from this response:  7
# Total # of Tweets added:  2000
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2017-05-01T00:00:00.000Z
# # of Tweets added from this response:  19
# Total # of Tweets added:  2019
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2017-06-01T00:00:00.000Z
# # of Tweets added from this response:  8
# Total # of Tweets added:  2027
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2017-07-01T00:00:00.000Z
# # of Tweets added from this response:  14
# Total # of Tweets added:  2041
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2017-08-01T00:00:00.000Z
# # of Tweets added from this response:  7
# Total # of Tweets added:  2048
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2017-10-01T00:00:00.000Z
# # of Tweets added from this response:  4
# Total # of Tweets added:  2052
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2017-11-01T00:00:00.000Z
# # of Tweets added from this response:  13
# Total # of Tweets added:  2065
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2017-12-01T00:00:00.000Z
# # of Tweets added from this response:  6
# Total # of Tweets added:  2071
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2018-01-01T00:00:00.000Z
# # of Tweets added from this response:  10
# Total # of Tweets added:  2081
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2018-02-01T00:00:00.000Z
# # of Tweets added from this response:  13
# Total # of Tweets added:  2094
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2018-03-01T00:00:00.000Z
# # of Tweets added from this response:  12
# Total # of Tweets added:  2106
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2018-04-01T00:00:00.000Z
# # of Tweets added from this response:  4
# Total # of Tweets added:  2110
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2018-05-01T00:00:00.000Z
# # of Tweets added from this response:  17
# Total # of Tweets added:  2127
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2018-06-01T00:00:00.000Z
# # of Tweets added from this response:  14
# Total # of Tweets added:  2141
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2018-07-01T00:00:00.000Z
# # of Tweets added from this response:  12
# Total # of Tweets added:  2153
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2018-08-01T00:00:00.000Z
# # of Tweets added from this response:  7
# Total # of Tweets added:  2160
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2018-09-01T00:00:00.000Z
# # of Tweets added from this response:  6
# Total # of Tweets added:  2166
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2018-10-01T00:00:00.000Z
# # of Tweets added from this response:  10
# Total # of Tweets added:  2176
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2018-11-01T00:00:00.000Z
# # of Tweets added from this response:  6
# Total # of Tweets added:  2182
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2018-12-01T00:00:00.000Z
# # of Tweets added from this response:  15
# Total # of Tweets added:  2197
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  9
# Total # of Tweets added:  2206
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2019-02-01T00:00:00.000Z
# # of Tweets added from this response:  14
# Total # of Tweets added:  2220
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2019-03-01T00:00:00.000Z
# # of Tweets added from this response:  18
# Total # of Tweets added:  2238
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2019-04-01T00:00:00.000Z
# # of Tweets added from this response:  13
# Total # of Tweets added:  2251
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2019-05-01T00:00:00.000Z
# # of Tweets added from this response:  11
# Total # of Tweets added:  2262
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2019-06-01T00:00:00.000Z
# # of Tweets added from this response:  32
# Total # of Tweets added:  2294
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2019-07-01T00:00:00.000Z
# # of Tweets added from this response:  10
# Total # of Tweets added:  2304
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2019-08-01T00:00:00.000Z
# # of Tweets added from this response:  9
# Total # of Tweets added:  2313
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2019-09-01T00:00:00.000Z
# # of Tweets added from this response:  9
# Total # of Tweets added:  2322
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2019-10-01T00:00:00.000Z
# # of Tweets added from this response:  6
# Total # of Tweets added:  2328
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2019-11-01T00:00:00.000Z
# # of Tweets added from this response:  5
# Total # of Tweets added:  2333
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2019-12-01T00:00:00.000Z
# # of Tweets added from this response:  9
# Total # of Tweets added:  2342
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2020-01-01T00:00:00.000Z
# # of Tweets added from this response:  10
# Total # of Tweets added:  2352
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2020-02-01T00:00:00.000Z
# # of Tweets added from this response:  9
# Total # of Tweets added:  2361
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2020-03-01T00:00:00.000Z
# # of Tweets added from this response:  9
# Total # of Tweets added:  2370
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2020-04-01T00:00:00.000Z
# # of Tweets added from this response:  47
# Total # of Tweets added:  2417
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2020-05-01T00:00:00.000Z
# # of Tweets added from this response:  8
# Total # of Tweets added:  2425
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2020-06-01T00:00:00.000Z
# # of Tweets added from this response:  12
# Total # of Tweets added:  2437
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2020-07-01T00:00:00.000Z
# # of Tweets added from this response:  9
# Total # of Tweets added:  2446
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2020-08-01T00:00:00.000Z
# # of Tweets added from this response:  38
# Total # of Tweets added:  2484
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2020-09-01T00:00:00.000Z
# # of Tweets added from this response:  4
# Total # of Tweets added:  2488
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2020-10-01T00:00:00.000Z
# # of Tweets added from this response:  13
# Total # of Tweets added:  2501
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2020-11-01T00:00:00.000Z
# # of Tweets added from this response:  16
# Total # of Tweets added:  2517
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2020-12-01T00:00:00.000Z
# # of Tweets added from this response:  12
# Total # of Tweets added:  2529
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2021-01-01T00:00:00.000Z
# # of Tweets added from this response:  28
# Total # of Tweets added:  2557
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2021-02-01T00:00:00.000Z
# # of Tweets added from this response:  27
# Total # of Tweets added:  2584
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2021-03-01T00:00:00.000Z
# # of Tweets added from this response:  4
# Total # of Tweets added:  2588
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2021-04-01T00:00:00.000Z
# # of Tweets added from this response:  23
# Total # of Tweets added:  2611
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2021-05-01T00:00:00.000Z
# # of Tweets added from this response:  9
# Total # of Tweets added:  2620
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2021-06-01T00:00:00.000Z
# # of Tweets added from this response:  4
# Total # of Tweets added:  2624
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2021-07-01T00:00:00.000Z
# # of Tweets added from this response:  7
# Total # of Tweets added:  2631
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2021-08-01T00:00:00.000Z
# # of Tweets added from this response:  12
# Total # of Tweets added:  2643
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2021-09-01T00:00:00.000Z
# # of Tweets added from this response:  15
# Total # of Tweets added:  2658
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2021-10-01T00:00:00.000Z
# # of Tweets added from this response:  26
# Total # of Tweets added:  2684
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2021-11-01T00:00:00.000Z
# # of Tweets added from this response:  22
# Total # of Tweets added:  2706
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2021-12-01T00:00:00.000Z
# # of Tweets added from this response:  48
# Total # of Tweets added:  2754
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2022-01-01T00:00:00.000Z
# # of Tweets added from this response:  179
# Total # of Tweets added:  2933
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2022-02-01T00:00:00.000Z
# # of Tweets added from this response:  19
# Total # of Tweets added:  2952
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# -------------------
# Start Date:  2022-03-01T00:00:00.000Z
# # of Tweets added from this response:  66
# Total # of Tweets added:  3018
# -------------------
# Total number of results:  3018
